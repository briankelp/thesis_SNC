# %%
import sys

# %%
import sys
# !{sys.executable} stateful-lstm-by-sequence_2 train csv_files_srsRAN_zmq/train_encoded.csv
# Out:
# 2026-05-05 19:14:05.733968: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sequences: 759, Features: 890, Max length (raw): 22
# Label distribution: (array([0., 1.], dtype=float32), array([528, 231]))
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777979727.449205   17283 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2140 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# ...

# %%
import sys
# !{sys.executable} pcap_to_csv_inference --pcap /tmp/ue_mac_nr.pcap --encoding-mode trained --artifacts-dir artifacts_2
# Out:
# tshark: The file "/tmp/ue_mac_nr.pcap" doesn't exist.
# Traceback (most recent call last):
#   File "/home/brian/thesis_stuff/thesis_SNC/thesis_SNC/pcap_to_csv_inference", line 322, in <module>
#     main()
#   File "/home/brian/thesis_stuff/thesis_SNC/thesis_SNC/pcap_to_csv_inference", line 309, in main
#     out = pcap_or_xml_to_infer_csv(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/brian/thesis_stuff/thesis_SNC/thesis_SNC/pcap_to_csv_inference", line 262, in pcap_or_xml_to_infer_csv
#     run_tshark_to_pdml(pcap_file, generated_xml)
#   File "/home/brian/thesis_stuff/thesis_SNC/thesis_SNC/pcap_to_csv_inference", line 161, in run_tshark_to_pdml
#     subprocess.run(["tshark", "-r", input_pcap, "-T", "pdml"], stdout=f, check=True)
#   File "/usr/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# ...

# %%
import sys
# !{sys.executable} stateful-lstm-by-sequence_2 infer csv_files/infer_input.csv
# Out:
# 2026-05-12 17:04:46.987619: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778576696.101983    7061 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2140 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# ...

# %%
# !{sys.executable} live_detection.py \
    --artifacts-dir artifacts_2/ \
    --interval 4 \
    --threshold 0.5 \
    --pcap /tmp/ue_mac_nr.pcap
# Out:
# 2026-05-05 19:26:16.645923: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777980380.873152   23930 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2140 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# [2026-05-05 19:26:21] ⚠️  FBS ATTACK DETECTED | Prob: 1.0000 | Packets: 8 | Predict time: 1541.8ms | Avg: 1541.8ms | Runs: 1 (✅0 ⚠️1)
# [2026-05-05 19:26:28] ⚠️  FBS ATTACK DETECTED | Prob: 1.0000 | Packets: 8 | Predict time: 81.6ms | Avg: 811.7ms | Runs: 2 (✅0 ⚠️2)
# ...

# %%
# !{sys.executable} analyze_results.py --csv hardware_results_filtered.csv
# Out:
# Loaded 574 results from hardware_results_filtered.csv
# Scenarios: ['reject_3', 'reject_6', 'reject_7', 'reject_9', 'reject_10', 'reject_11', 'reject_12', 'reject_13', 'reject_15', 'reject_20', 'reject_21', 'reject_22', 'reject_23', 'reject_24', 'reject_26', 'reject_27', 'reject_28', 'reject_43', 'reject_65', 'reject_67', 'reject_69', 'reject_71', 'reject_72', 'reject_73', 'reject_90', 'reject_91', 'reject_92', 'benign', 'authentication_reject']
#
# ...
#   OVERALL HARDWARE RESULTS
# ...
#   TP=104  TN=465  FP=3  FN=2
#   Accuracy:  0.9913 (99.13%)
#   Precision: 0.9720 (97.20%)
#   Recall:    0.9811 (98.11%)
#   FPR:       0.0064 (0.64%)
#   F1-Score:  0.9765 (97.65%)
#
#   Confusion Matrix:
#                    Predicted Benign   Predicted Attack
#   Actual Benign       465                  3
#   Actual Attack       2                    104
# ...
#
#   PER-SCENARIO BREAKDOWN
# ...
#   Scenario                   Runs   TP   TN   FP   FN     Acc   Recall
# ...
